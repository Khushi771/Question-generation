# %%
# !pip3 install pyngrok
# Out:
# Collecting pyngrok
#   Downloading pyngrok-7.0.3-py3-none-any.whl (21 kB)
# Requirement already satisfied: PyYAML in /Users/khushi/anaconda3/lib/python3.11/site-packages (from pyngrok) (6.0)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-7.0.3

# %%
# !pip3 install streamlit
# Out:
# Requirement already satisfied: streamlit in /Users/khushi/anaconda3/lib/python3.11/site-packages (1.29.0)
# Requirement already satisfied: altair<6,>=4.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit) (5.2.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit) (1.7.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit) (5.3.1)
# Requirement already satisfied: click<9,>=7.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit) (1.26.1)
# Requirement already satisfied: packaging<24,>=16.8 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit) (23.0)
# Requirement already satisfied: pandas<3,>=1.3.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit) (1.5.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit) (4.21.12)
# Requirement already satisfied: pyarrow>=6.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit) (2.29.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit) (13.7.0)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit) (4.9.0)
# Requirement already satisfied: tzlocal<6,>=1.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit) (5.2)
# Requirement already satisfied: validators<1,>=0.2 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit) (0.22.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit) (3.1.40)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit) (6.2)
# Requirement already satisfied: jinja2 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: toolz in /Users/khushi/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from importlib-metadata<7,>=1.4->streamlit) (3.11.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from pandas<3,>=1.3.0->streamlit) (2022.7)
# Requirement already satisfied: six>=1.5 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from python-dateutil<3,>=2.7.3->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit) (2023.5.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from rich<14,>=10.14.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from rich<14,>=10.14.0->streamlit) (2.15.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.0)

# %%
# !pip3 install scapy
# Out:
# Collecting scapy
#   Downloading scapy-2.5.0.tar.gz (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 3.9 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: scapy
#   Building wheel for scapy (setup.py) ... done
#   Created wheel for scapy: filename=scapy-2.5.0-py2.py3-none-any.whl size=1444326 sha256=e95edce595c172181b85430193e111b0fb85c7c7251dc84441fde9292f022968
#   Stored in directory: /Users/khushi/Library/Caches/pip/wheels/11/ff/28/a1348d0c6d006242c053521732bc2951d0c9eca62a11430da1
# Successfully built scapy
# Installing collected packages: scapy
# Successfully installed scapy-2.5.0

# %%
# !pip3 install benepar
# Out:
# Collecting benepar
#   Downloading benepar-0.2.0.tar.gz (33 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nltk>=3.2 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from benepar) (3.7)
# Requirement already satisfied: spacy>=2.0.9 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from benepar) (3.7.2)
# Requirement already satisfied: torch>=1.6.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from benepar) (2.1.0)
# Collecting torch-struct>=0.5 (from benepar)
#   Downloading torch_struct-0.5-py3-none-any.whl (34 kB)
# Requirement already satisfied: tokenizers>=0.9.4 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from benepar) (0.15.0)
# Requirement already satisfied: transformers[tokenizers,torch]>=4.2.2 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from benepar) (4.37.0.dev0)
# Requirement already satisfied: protobuf in /Users/khushi/anaconda3/lib/python3.11/site-packages (from benepar) (4.21.12)
# Requirement already satisfied: sentencepiece>=0.1.91 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from benepar) (0.1.99)
# Requirement already satisfied: click in /Users/khushi/anaconda3/lib/python3.11/site-packages (from nltk>=3.2->benepar) (8.0.4)
# Requirement already satisfied: joblib in /Users/khushi/anaconda3/lib/python3.11/site-packages (from nltk>=3.2->benepar) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from nltk>=3.2->benepar) (2022.7.9)
# Requirement already satisfied: tqdm in /Users/khushi/anaconda3/lib/python3.11/site-packages (from nltk>=3.2->benepar) (4.65.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy>=2.0.9->benepar) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy>=2.0.9->benepar) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy>=2.0.9->benepar) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy>=2.0.9->benepar) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy>=2.0.9->benepar) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy>=2.0.9->benepar) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy>=2.0.9->benepar) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy>=2.0.9->benepar) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy>=2.0.9->benepar) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy>=2.0.9->benepar) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy>=2.0.9->benepar) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy>=2.0.9->benepar) (5.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy>=2.0.9->benepar) (2.29.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy>=2.0.9->benepar) (2.5.2)
# Requirement already satisfied: jinja2 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy>=2.0.9->benepar) (3.1.2)
# Requirement already satisfied: setuptools in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy>=2.0.9->benepar) (67.8.0)
# Requirement already satisfied: packaging>=20.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy>=2.0.9->benepar) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy>=2.0.9->benepar) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy>=2.0.9->benepar) (1.26.1)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from tokenizers>=0.9.4->benepar) (0.20.1)
# Requirement already satisfied: filelock in /Users/khushi/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->benepar) (3.9.0)
# Requirement already satisfied: typing-extensions in /Users/khushi/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->benepar) (4.9.0)
# Requirement already satisfied: sympy in /Users/khushi/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->benepar) (1.11.1)
# Requirement already satisfied: networkx in /Users/khushi/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->benepar) (2.8.4)
# Requirement already satisfied: fsspec in /Users/khushi/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->benepar) (2023.12.2)
# Requirement already satisfied: pyyaml>=5.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from transformers[tokenizers,torch]>=4.2.2->benepar) (6.0)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from transformers[tokenizers,torch]>=4.2.2->benepar) (0.4.1)
# Collecting accelerate>=0.21.0 (from transformers[tokenizers,torch]>=4.2.2->benepar)
#   Downloading accelerate-0.25.0-py3-none-any.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 2.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: psutil in /Users/khushi/anaconda3/lib/python3.11/site-packages (from accelerate>=0.21.0->transformers[tokenizers,torch]>=4.2.2->benepar) (5.9.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.0.9->benepar) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.0.9->benepar) (2.14.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.0.9->benepar) (2023.5.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy>=2.0.9->benepar) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy>=2.0.9->benepar) (0.1.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spacy>=2.0.9->benepar) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jinja2->spacy>=2.0.9->benepar) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.6.0->benepar) (1.2.1)
# Building wheels for collected packages: benepar
#   Building wheel for benepar (setup.py) ... done
#   Created wheel for benepar: filename=benepar-0.2.0-py3-none-any.whl size=37624 sha256=df9d863ccc1d646f2029b4039abccc99148af1e4efc6bc3018156ac8bd18448e
#   Stored in directory: /Users/khushi/Library/Caches/pip/wheels/a7/06/97/846995c0825bbc92825ce41675b6d5477213b25e167115223f
# Successfully built benepar
# Installing collected packages: torch-struct, accelerate, benepar
# Successfully installed accelerate-0.25.0 benepar-0.2.0 torch-struct-0.5

# %%
import nltk
nltk.download("all")
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/biocreative_ppi.zip.
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping models/bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping grammars/book_grammars.zip.
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown.zip.
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/brown_tei.zip.
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_cat.zip.
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/city_database.zip.
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/dolch.zip.
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/europarl_raw.zip.
# [nltk_data]    | Downloading package extended_omw to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/ieer.zip.
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/indian.zip.
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/kimmo.zip.
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping grammars/large_grammars.zip.
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/mac_morpho.zip.
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping taggers/maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping models/moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/mte_teip5.zip.
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping misc/mwa_ppdb.zip.
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/nonbreaking_prefixes.zip.
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to /Users/khushi/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/opinion_lexicon.zip.
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/paradigms.zip.
# [nltk_data]    | Downloading package pe08 to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/pe08.zip.
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping misc/perluniprops.zip.
# [nltk_data]    | Downloading package pil to /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/pil.zip.
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/pl196x.zip.
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping stemmers/porter_test.zip.
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/problem_reports.zip.
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/product_reviews_2.zip.
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/pros_cons.zip.
# [nltk_data]    | Downloading package ptb to /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/ptb.zip.
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping tokenizers/punkt.zip.
# [nltk_data]    | Downloading package qc to /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/qc.zip.
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping stemmers/rslp.zip.
# [nltk_data]    | Downloading package rte to /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/rte.zip.
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping grammars/sample_grammars.zip.
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/senseval.zip.
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentence_polarity.zip.
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/sentiwordnet.zip.
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/smultron.zip.
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping grammars/spanish_grammars.zip.
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/state_union.zip.
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/swadesh.zip.
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/switchboard.zip.
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping help/tagsets.zip.
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/timit.zip.
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/toolbox.zip.
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr.zip.
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/unicode_samples.zip.
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping taggers/universal_tagset.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet.zip.
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/verbnet3.zip.
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/webtext.zip.
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping models/wmt15_eval.zip.
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping models/word2vec_sample.zip.
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    | Downloading package wordnet2022 to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/wordnet2022.zip.
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     /Users/khushi/nltk_data...
# [nltk_data]    |   Unzipping corpora/ycoe.zip.
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
from pyngrok import ngrok
import os

# %%
ngrok.set_auth_token("2a4oupbB51av4FjMDBIEe3CGrDA_5G8Kz4gK3ukBXtsKP2g9p")

# %%
# !pip3 install streamlit_jupyter
# Out:
# Requirement already satisfied: streamlit_jupyter in /Users/khushi/anaconda3/lib/python3.11/site-packages (0.2.1)
# Requirement already satisfied: fastcore in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit_jupyter) (1.5.29)
# Requirement already satisfied: ipywidgets==7.7.2 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit_jupyter) (7.7.2)
# Requirement already satisfied: jupyter in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit_jupyter) (1.0.0)
# Requirement already satisfied: stqdm in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit_jupyter) (0.0.5)
# Requirement already satisfied: streamlit>=1.19 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit_jupyter) (1.29.0)
# Requirement already satisfied: tabulate in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit_jupyter) (0.8.10)
# Requirement already satisfied: tqdm in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit_jupyter) (4.65.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from ipywidgets==7.7.2->streamlit_jupyter) (6.19.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from ipywidgets==7.7.2->streamlit_jupyter) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from ipywidgets==7.7.2->streamlit_jupyter) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from ipywidgets==7.7.2->streamlit_jupyter) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from ipywidgets==7.7.2->streamlit_jupyter) (8.12.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from ipywidgets==7.7.2->streamlit_jupyter) (1.1.7)
# Requirement already satisfied: altair<6,>=4.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit>=1.19->streamlit_jupyter) (5.2.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit>=1.19->streamlit_jupyter) (1.7.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit>=1.19->streamlit_jupyter) (5.3.1)
# Requirement already satisfied: click<9,>=7.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit>=1.19->streamlit_jupyter) (8.0.4)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit>=1.19->streamlit_jupyter) (6.0.0)
# Requirement already satisfied: numpy<2,>=1.19.3 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit>=1.19->streamlit_jupyter) (1.26.2)
# Requirement already satisfied: packaging<24,>=16.8 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit>=1.19->streamlit_jupyter) (23.0)
# Requirement already satisfied: pandas<3,>=1.3.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit>=1.19->streamlit_jupyter) (1.5.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit>=1.19->streamlit_jupyter) (9.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit>=1.19->streamlit_jupyter) (4.21.12)
# Requirement already satisfied: pyarrow>=6.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit>=1.19->streamlit_jupyter) (11.0.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit>=1.19->streamlit_jupyter) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit>=1.19->streamlit_jupyter) (2.29.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit>=1.19->streamlit_jupyter) (13.7.0)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit>=1.19->streamlit_jupyter) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit>=1.19->streamlit_jupyter) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit>=1.19->streamlit_jupyter) (4.9.0)
# Requirement already satisfied: tzlocal<6,>=1.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit>=1.19->streamlit_jupyter) (5.2)
# Requirement already satisfied: validators<1,>=0.2 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit>=1.19->streamlit_jupyter) (0.22.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit>=1.19->streamlit_jupyter) (3.1.40)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit>=1.19->streamlit_jupyter) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from streamlit>=1.19->streamlit_jupyter) (6.2)
# Requirement already satisfied: pip in /Users/khushi/anaconda3/lib/python3.11/site-packages (from fastcore->streamlit_jupyter) (23.1.2)
# Requirement already satisfied: notebook in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jupyter->streamlit_jupyter) (6.5.4)
# Requirement already satisfied: qtconsole in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jupyter->streamlit_jupyter) (5.4.2)
# Requirement already satisfied: jupyter-console in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jupyter->streamlit_jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jupyter->streamlit_jupyter) (6.5.4)
# Requirement already satisfied: jinja2 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit>=1.19->streamlit_jupyter) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit>=1.19->streamlit_jupyter) (4.17.3)
# Requirement already satisfied: toolz in /Users/khushi/anaconda3/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit>=1.19->streamlit_jupyter) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.19->streamlit_jupyter) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from importlib-metadata<7,>=1.4->streamlit>=1.19->streamlit_jupyter) (3.11.0)
# Requirement already satisfied: appnope in /Users/khushi/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter) (0.1.2)
# Requirement already satisfied: comm>=0.1.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter) (1.5.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter) (8.1.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter) (0.1.6)
# Requirement already satisfied: nest-asyncio in /Users/khushi/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter) (1.5.6)
# Requirement already satisfied: psutil in /Users/khushi/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter) (5.9.0)
# Requirement already satisfied: pyzmq>=17 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit_jupyter) (25.1.0)
# Requirement already satisfied: backcall in /Users/khushi/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (0.2.0)
# Requirement already satisfied: decorator in /Users/khushi/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (0.18.1)
# Requirement already satisfied: pickleshare in /Users/khushi/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (2.15.1)
# Requirement already satisfied: stack-data in /Users/khushi/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (4.8.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from pandas<3,>=1.3.0->streamlit>=1.19->streamlit_jupyter) (2022.7)
# Requirement already satisfied: six>=1.5 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from python-dateutil<3,>=2.7.3->streamlit>=1.19->streamlit_jupyter) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit>=1.19->streamlit_jupyter) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit>=1.19->streamlit_jupyter) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit>=1.19->streamlit_jupyter) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit>=1.19->streamlit_jupyter) (2023.5.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from rich<14,>=10.14.0->streamlit>=1.19->streamlit_jupyter) (2.2.0)
# Requirement already satisfied: argon2-cffi in /Users/khushi/anaconda3/lib/python3.11/site-packages (from notebook->jupyter->streamlit_jupyter) (21.3.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from notebook->jupyter->streamlit_jupyter) (5.3.0)
# Requirement already satisfied: nbformat in /Users/khushi/anaconda3/lib/python3.11/site-packages (from notebook->jupyter->streamlit_jupyter) (5.7.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from notebook->jupyter->streamlit_jupyter) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from notebook->jupyter->streamlit_jupyter) (0.17.1)
# Requirement already satisfied: prometheus-client in /Users/khushi/anaconda3/lib/python3.11/site-packages (from notebook->jupyter->streamlit_jupyter) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from notebook->jupyter->streamlit_jupyter) (0.5.5)
# Requirement already satisfied: lxml in /Users/khushi/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->streamlit_jupyter) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->streamlit_jupyter) (4.12.2)
# Requirement already satisfied: bleach in /Users/khushi/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->streamlit_jupyter) (4.1.0)
# Requirement already satisfied: defusedxml in /Users/khushi/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->streamlit_jupyter) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->streamlit_jupyter) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /Users/khushi/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->streamlit_jupyter) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->streamlit_jupyter) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->streamlit_jupyter) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->streamlit_jupyter) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->streamlit_jupyter) (1.5.0)
# Requirement already satisfied: tinycss2 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from nbconvert->jupyter->streamlit_jupyter) (1.2.1)
# Requirement already satisfied: qtpy>=2.0.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from qtconsole->jupyter->streamlit_jupyter) (2.2.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.19->streamlit_jupyter) (5.0.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.19->streamlit_jupyter) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.19->streamlit_jupyter) (0.18.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jupyter-core>=4.6.1->notebook->jupyter->streamlit_jupyter) (2.5.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit>=1.19->streamlit_jupyter) (0.1.0)
# Requirement already satisfied: jupyter-server>=1.8 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from nbclassic>=0.4.7->notebook->jupyter->streamlit_jupyter) (2.5.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from nbclassic>=0.4.7->notebook->jupyter->streamlit_jupyter) (0.2.2)
# Requirement already satisfied: fastjsonschema in /Users/khushi/anaconda3/lib/python3.11/site-packages (from nbformat->notebook->jupyter->streamlit_jupyter) (2.16.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/khushi/anaconda3/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (0.2.5)
# Requirement already satisfied: argon2-cffi-bindings in /Users/khushi/anaconda3/lib/python3.11/site-packages (from argon2-cffi->notebook->jupyter->streamlit_jupyter) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from beautifulsoup4->nbconvert->jupyter->streamlit_jupyter) (2.4)
# Requirement already satisfied: webencodings in /Users/khushi/anaconda3/lib/python3.11/site-packages (from bleach->nbconvert->jupyter->streamlit_jupyter) (0.5.1)
# Requirement already satisfied: executing in /Users/khushi/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (0.8.3)
# Requirement already satisfied: asttokens in /Users/khushi/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/khushi/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.7.2->streamlit_jupyter) (0.2.2)
# Requirement already satisfied: anyio>=3.1.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->streamlit_jupyter) (3.5.0)
# Requirement already satisfied: jupyter-events>=0.4.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->streamlit_jupyter) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->streamlit_jupyter) (0.4.4)
# Requirement already satisfied: websocket-client in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->streamlit_jupyter) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->streamlit_jupyter) (1.15.1)
# Requirement already satisfied: sniffio>=1.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->streamlit_jupyter) (1.2.0)
# Requirement already satisfied: pycparser in /Users/khushi/anaconda3/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->streamlit_jupyter) (2.21)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->streamlit_jupyter) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->streamlit_jupyter) (6.0)
# Requirement already satisfied: rfc3339-validator in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->streamlit_jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook->jupyter->streamlit_jupyter) (0.1.1)
# Requirement already satisfied: fqdn in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.19->streamlit_jupyter) (1.5.1)
# Requirement already satisfied: isoduration in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.19->streamlit_jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.19->streamlit_jupyter) (2.1)
# Requirement already satisfied: uri-template in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.19->streamlit_jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.19->streamlit_jupyter) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from isoduration->jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.19->streamlit_jupyter) (1.2.3)

# %%
# !pip3 install bert-extractive-summarizer
# !pip3 install transformers
# !pip3 install -U sentence-transformers
# !pip3 install git+https://github.com/boudinfl/pke.git

# %%
# !pip3 install yake
# !pip3 install keyBert
# !pip3 install flashtext
# Out:
# Requirement already satisfied: yake in /Users/khushi/anaconda3/lib/python3.11/site-packages (0.4.8)
# Requirement already satisfied: tabulate in /Users/khushi/anaconda3/lib/python3.11/site-packages (from yake) (0.8.10)
# Requirement already satisfied: click>=6.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from yake) (8.0.4)
# Requirement already satisfied: numpy in /Users/khushi/anaconda3/lib/python3.11/site-packages (from yake) (1.26.1)
# Requirement already satisfied: segtok in /Users/khushi/anaconda3/lib/python3.11/site-packages (from yake) (1.5.11)
# Requirement already satisfied: networkx in /Users/khushi/anaconda3/lib/python3.11/site-packages (from yake) (2.8.4)
# Requirement already satisfied: jellyfish in /Users/khushi/anaconda3/lib/python3.11/site-packages (from yake) (0.9.0)
# Requirement already satisfied: regex in /Users/khushi/anaconda3/lib/python3.11/site-packages (from segtok->yake) (2022.7.9)
# Requirement already satisfied: keyBert in /Users/khushi/anaconda3/lib/python3.11/site-packages (0.8.3)
# Requirement already satisfied: sentence-transformers>=0.3.8 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from keyBert) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22.2 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from keyBert) (1.2.2)
# Requirement already satisfied: numpy>=1.18.5 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from keyBert) (1.26.1)
# Requirement already satisfied: rich>=10.4.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from keyBert) (13.7.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from rich>=10.4.0->keyBert) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from rich>=10.4.0->keyBert) (2.15.1)
# Requirement already satisfied: scipy>=1.3.2 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.22.2->keyBert) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.22.2->keyBert) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.22.2->keyBert) (2.2.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from sentence-transformers>=0.3.8->keyBert) (4.37.0.dev0)
# Requirement already satisfied: tqdm in /Users/khushi/anaconda3/lib/python3.11/site-packages (from sentence-transformers>=0.3.8->keyBert) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from sentence-transformers>=0.3.8->keyBert) (2.1.0)
# Requirement already satisfied: torchvision in /Users/khushi/anaconda3/lib/python3.11/site-packages (from sentence-transformers>=0.3.8->keyBert) (0.16.0)
# Requirement already satisfied: nltk in /Users/khushi/anaconda3/lib/python3.11/site-packages (from sentence-transformers>=0.3.8->keyBert) (3.7)
# Requirement already satisfied: sentencepiece in /Users/khushi/anaconda3/lib/python3.11/site-packages (from sentence-transformers>=0.3.8->keyBert) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from sentence-transformers>=0.3.8->keyBert) (0.20.1)
# Requirement already satisfied: filelock in /Users/khushi/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keyBert) (3.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keyBert) (2023.12.2)
# Requirement already satisfied: requests in /Users/khushi/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keyBert) (2.29.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keyBert) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keyBert) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keyBert) (23.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.4.0->keyBert) (0.1.0)
# Requirement already satisfied: sympy in /Users/khushi/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keyBert) (1.11.1)
# Requirement already satisfied: networkx in /Users/khushi/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keyBert) (2.8.4)
# Requirement already satisfied: jinja2 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence-transformers>=0.3.8->keyBert) (3.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keyBert) (2022.7.9)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keyBert) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keyBert) (0.4.1)
# Requirement already satisfied: click in /Users/khushi/anaconda3/lib/python3.11/site-packages (from nltk->sentence-transformers>=0.3.8->keyBert) (8.0.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from torchvision->sentence-transformers>=0.3.8->keyBert) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.3.8->keyBert) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keyBert) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keyBert) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keyBert) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keyBert) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.3.8->keyBert) (1.2.1)
# Requirement already satisfied: flashtext in /Users/khushi/anaconda3/lib/python3.11/site-packages (2.7)

# %%
# !pip3 install git+https://github.com/plandes/self-attentive-parser -qqq

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
# !python -m spacy download en_core_web_md
# Out:
# Collecting en-core-web-md==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.7.1/en_core_web_md-3.7.1-py3-none-any.whl (42.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 1.1 MB/s eta 0:00:0000:01m00:02
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from en-core-web-md==3.7.1) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (8.2.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.29.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.5.2)
# Requirement already satisfied: jinja2 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (67.8.0)
# Requirement already satisfied: packaging>=20.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.26.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2023.5.7)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.1.1)
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
import benepar
benepar.download('benepar_en3')

# %%
# !pip3 install summa
# !pip3 install sentence_transformers

# %%
# !pip3 install pywsd
# Out:
# Requirement already satisfied: pywsd in /Users/khushi/anaconda3/lib/python3.11/site-packages (1.2.5)
# Requirement already satisfied: nltk in /Users/khushi/anaconda3/lib/python3.11/site-packages (from pywsd) (3.7)
# Requirement already satisfied: numpy in /Users/khushi/anaconda3/lib/python3.11/site-packages (from pywsd) (1.26.1)
# Requirement already satisfied: pandas in /Users/khushi/anaconda3/lib/python3.11/site-packages (from pywsd) (1.5.3)
# Requirement already satisfied: wn==0.0.23 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from pywsd) (0.0.23)
# Requirement already satisfied: six in /Users/khushi/anaconda3/lib/python3.11/site-packages (from pywsd) (1.16.0)
# Requirement already satisfied: click in /Users/khushi/anaconda3/lib/python3.11/site-packages (from nltk->pywsd) (8.0.4)
# Requirement already satisfied: joblib in /Users/khushi/anaconda3/lib/python3.11/site-packages (from nltk->pywsd) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from nltk->pywsd) (2022.7.9)
# Requirement already satisfied: tqdm in /Users/khushi/anaconda3/lib/python3.11/site-packages (from nltk->pywsd) (4.65.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from pandas->pywsd) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from pandas->pywsd) (2022.7)

# %%
# !pip3 install import-ipynb
# Out:
# Collecting import-ipynb
#   Downloading import_ipynb-0.1.4-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: IPython in /Users/khushi/anaconda3/lib/python3.11/site-packages (from import-ipynb) (8.12.0)
# Requirement already satisfied: nbformat in /Users/khushi/anaconda3/lib/python3.11/site-packages (from import-ipynb) (5.7.0)
# Requirement already satisfied: backcall in /Users/khushi/anaconda3/lib/python3.11/site-packages (from IPython->import-ipynb) (0.2.0)
# Requirement already satisfied: decorator in /Users/khushi/anaconda3/lib/python3.11/site-packages (from IPython->import-ipynb) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from IPython->import-ipynb) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /Users/khushi/anaconda3/lib/python3.11/site-packages (from IPython->import-ipynb) (0.1.6)
# Requirement already satisfied: pickleshare in /Users/khushi/anaconda3/lib/python3.11/site-packages (from IPython->import-ipynb) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from IPython->import-ipynb) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from IPython->import-ipynb) (2.15.1)
# Requirement already satisfied: stack-data in /Users/khushi/anaconda3/lib/python3.11/site-packages (from IPython->import-ipynb) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from IPython->import-ipynb) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from IPython->import-ipynb) (4.8.0)
# Requirement already satisfied: appnope in /Users/khushi/anaconda3/lib/python3.11/site-packages (from IPython->import-ipynb) (0.1.2)
# Requirement already satisfied: fastjsonschema in /Users/khushi/anaconda3/lib/python3.11/site-packages (from nbformat->import-ipynb) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from nbformat->import-ipynb) (4.17.3)
# Requirement already satisfied: jupyter-core in /Users/khushi/anaconda3/lib/python3.11/site-packages (from nbformat->import-ipynb) (5.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->IPython->import-ipynb) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.18.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from pexpect>4.3->IPython->import-ipynb) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/khushi/anaconda3/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->IPython->import-ipynb) (0.2.5)
# Requirement already satisfied: platformdirs>=2.5 in /Users/khushi/anaconda3/lib/python3.11/site-packages (from jupyter-core->nbformat->import-ipynb) (2.5.2)
# Requirement already satisfied: executing in /Users/khushi/anaconda3/lib/python3.11/site-packages (from stack-data->IPython->import-ipynb) (0.8.3)
# Requirement already satisfied: asttokens in /Users/khushi/anaconda3/lib/python3.11/site-packages (from stack-data->IPython->import-ipynb) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/khushi/anaconda3/lib/python3.11/site-packages (from stack-data->IPython->import-ipynb) (0.2.2)
# Requirement already satisfied: six in /Users/khushi/anaconda3/lib/python3.11/site-packages (from asttokens->stack-data->IPython->import-ipynb) (1.16.0)
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.4

# %%
# %%writefile app.py

import requests
import json
import re
import random
import scapy
import string
import scipy
from string import punctuation
from nltk import tokenize
from pywsd.similarity import max_similarity
from pywsd.lesk import adapted_lesk, simple_lesk, cosine_lesk
from nltk.corpus import wordnet as wn
from nltk.tokenize import sent_tokenize
from flashtext import KeywordProcessor
import yake
from keybert import KeyBERT
from summarizer import Summarizer
import nltk
import io
from IPython.display import Markdown, display
from random import shuffle
from io import StringIO
from transformers import GPT2LMHeadModel, GPT2Tokenizer
from sentence_transformers import SentenceTransformer
import torch
import benepar
benepar.download('benepar_en3')
parser = benepar.Parser("benepar_en3")
import streamlit as st
import os

import import_ipynb
import mcq
import Generatingblanks

st.set_page_config(
    page_title = "MCQ Generator"
)

uploaded_file = st.file_uploader("Upload the text file", type={"txt"})
if uploaded_file is not None:
    full_text = uploaded_file.getvalue().decode('utf-8')
    if st.button('Start'):
        st.write('Started...')
    summarized_text = Generatingblanks.bert_summ(full_text)
    kw_summ = Generatingblanks.keyword_selection(summarized_text)
    kw_full = Generatingblanks.keyword_selection(full_text)
    filtered_keys1 = []
    for keyword in kw_summ:
        if keyword.lower() in summarized_text.lower():
            filtered_keys1.append(keyword)
    filtered_keys2 = []
    for keyword in kw_full:
        if keyword.lower() in full_text.lower():
            filtered_keys2.append(keyword)
    sentences1 = Generatingblanks.SentenceMapping.tokenize_sentences(summarized_text)
    keyword_sentence_mapping1 = Generatingblanks.SentenceMapping.get_sentences_for_keyword(filtered_keys1, sentences1)
    sentences2 = Generatingblanks.SentenceMapping.tokenize_sentences(full_text)
    keyword_sentence_mapping2 = Generatingblanks.SentenceMapping.get_sentences_for_keyword(filtered_keys2, sentences2)
    kws_m =  keyword_sentence_mapping2.copy()
    kws_m.update(keyword_sentence_mapping1)

    mcq.Distractors.generate_option(kws_m)
# Out:
# Overwriting app.py

# %%
import os
from streamlit_jupyter import StreamlitPatcher
StreamlitPatcher().jupyter()
# !nohup streamlit run app.ipynb --server.port 80 &
# url = ngrok.connect(port = '80')
# print(url)
from pyngrok import ngrok
public_url = ngrok.connect(port='80')
print (public_url)
# !streamlit run --server.port 80 app.py >/dev/null
# Out:
# t=2023-12-29T15:00:05+0530 lvl=warn msg="invalid tunnel configuration" pg=/api/tunnels id=b8bf25b36a78ca5b err="yaml: unmarshal errors:\n  line 1: field port not found in type config.HTTPv2Tunnel"
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pyngrok/ngrok.py:507, in api_request(url, method, data, params, timeout, auth)
#     506 try:
# --> 507     response = urlopen(request, encoded_data, timeout)
#     508     response_data = response.read().decode("utf-8")
#
# File ~/anaconda3/lib/python3.11/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File ~/anaconda3/lib/python3.11/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File ~/anaconda3/lib/python3.11/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File ~/anaconda3/lib/python3.11/urllib/request.py:563, in OpenerDirector.error(self, proto, *args)
#     562 args = (dict, 'default', 'http_error_default') + orig_args
# --> 563 return self._call_chain(*args)
#
# File ~/anaconda3/lib/python3.11/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     495 func = getattr(handler, meth_name)
# --> 496 result = func(*args)
#     497 if result is not None:
#
# File ~/anaconda3/lib/python3.11/urllib/request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 400: Bad Request
#
# During handling of the above exception, another exception occurred:
#
# PyngrokNgrokHTTPError                     Traceback (most recent call last)
# Cell In[4], line 8
#       4 # !nohup streamlit run app.ipynb --server.port 80 &
#       5 # url = ngrok.connect(port = '80')
#       6 # print(url)
#       7 from pyngrok import ngrok
# ----> 8 public_url = ngrok.connect(port='80')
#       9 print (public_url)
#      10 get_ipython().system('streamlit run --server.port 80 app.py >/dev/null')
#
# File ~/anaconda3/lib/python3.11/site-packages/pyngrok/ngrok.py:313, in connect(addr, proto, name, pyngrok_config, **options)
#     309 api_url = get_ngrok_process(pyngrok_config).api_url
#     311 logger.debug("Creating tunnel with options: {}".format(options))
# --> 313 tunnel = NgrokTunnel(api_request("{}/api/tunnels".format(api_url), method="POST", data=options,
#     314                                  timeout=pyngrok_config.request_timeout),
#     315                      pyngrok_config, api_url)
#     317 if pyngrok_config.ngrok_version == "v2" and proto == "http" and options.get("bind_tls", "both") == "both":
#     318     tunnel = NgrokTunnel(api_request("{}{}%20%28http%29".format(api_url, tunnel.uri), method="GET",
#     319                                      timeout=pyngrok_config.request_timeout),
#     320                          pyngrok_config, api_url)
#
# File ~/anaconda3/lib/python3.11/site-packages/pyngrok/ngrok.py:528, in api_request(url, method, data, params, timeout, auth)
#     525     status_code = e.getcode()
#     526     logger.debug("Response {}: {}".format(status_code, response_data.strip()))
# --> 528     raise PyngrokNgrokHTTPError("ngrok client exception, API returned {}: {}".format(status_code, response_data),
#     529                                 e.url,
#     530                                 status_code, e.reason, e.headers, response_data)
#     531 except URLError as e:
#     532     raise PyngrokNgrokURLError("ngrok client exception, URLError: {}".format(e.reason), e.reason)
#
# PyngrokNgrokHTTPError: ngrok client exception, API returned 400: {"error_code":102,"status_code":400,"msg":"invalid tunnel configuration","details":{"err":"yaml: unmarshal errors:\n  line 1: field port not found in type config.HTTPv2Tunnel"}}
